# %%
print("hello world")
a = 10
# Out:
# hello world

# %%
def add_one(i):
    return i+1

# %%
def retrieve_words(f):
    
    fulltext = f.read()
    list0Text = fulltext.split(" ")
    return list0Text

# %%
f = open("odyssey.txt", "r")
word_list = retrieve_words(f)

# %%
word_list
# Out:
# ['\nThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'The',
#  'Odyssey,',
#  'by',
#  'Homer\n\nThis',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and\nmost',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions\nwhatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms\nof',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at\nwww.gutenberg.org.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States,',
#  'you\nwill',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
#  'before\nusing',
#  'this',
# ...
